# %%
import sys
import os

# For Jupyter notebooks
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Import commonly used modules
from data_utils import *
from model_utils import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
from numba import cuda
import gc
from tensorflow.keras import backend as K
import numpy as np

from config_utils import load_config

# Load default config
CONFIG = load_config('../config/fl_template_config.yaml')

# Export commonly used items
__all__ = ['CONFIG']
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# 2025-03-27 14:49:03.092863: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743108543.164071   19610 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743108543.188907   19610 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743108543.325030   19610 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743108543.325167   19610 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743108543.325171   19610 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743108543.325173   19610 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-27 14:49:03.363925: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## FedAvg

# %% [markdown]
# ### Federated Learning Averaging Pseudocode
#
# ### Server Initialization:
# Initialize global model weights W₀
#
# ### Main Federated Learning Loop:
# For each round t = 1 to T:
#
#     1. Select a subset of clients Sₜ (or use all available clients)
#
#     2. Broadcast the current global model weights Wₜ to all clients in Sₜ
#
#     3. For each client k in Sₜ (executed in parallel):
#          - Perform a local update:
#            Wₜᵏ = ClientUpdate(Wₜ, local_dataₖ)
#          - Return updated local model weights Wₜᵏ along with the number of samples nₖ
#
#     4. Aggregate the updated weights using weighted averaging (FedAvg):
#          - Compute total samples: N = Σₖ₍∈Sₜ₎ nₖ
#          - Update global model weights:
#            Wₜ₊₁ = Σₖ₍∈Sₜ₎ (nₖ / N) * Wₜᵏ
#
# Return final global model weights W_T
#
# ### ClientUpdate Function:
# Function ClientUpdate(W, local_data):
#
#     - Set W_local = W
#
#     - For each local epoch e = 1 to E:
#          - For each batch b in local_data:
#               - Compute gradient: grad = ∇(loss(W_local, b))
#               - Update local weights: W_local = W_local - learning_rate * grad
#
#     Return W_local

# %% [markdown]
# #### Central Model Initialization

# %%
import os
import numpy as np
from tensorflow.keras.models import Model
from typing import Dict
import os
import numpy as np
from typing import List, Dict
from tensorflow.keras.models import Model

def save_model_weights(model: Model, client_id: str, folder_dir: str):
    """Save a model's weights to a .npy file in folder_dir."""
    os.makedirs(folder_dir, exist_ok=True)
    weights = model.get_weights()
    filepath = os.path.join(folder_dir, f"{client_id}_weights.npz")
    np.savez(filepath, *weights)

def load_all_weights(folder_dir: str) -> Dict[str, list]:
    client_weights = {}
    for file in os.listdir(folder_dir):
        if file.endswith("_weights.npz"):
            client_id = file.replace("_weights.npz", "")
            data = np.load(os.path.join(folder_dir, file))
            weights = [data[f'arr_{i}'] for i in range(len(data.files))]
            client_weights[client_id] = weights
    return client_weights

def load_model_weights(weight_path: str):
    data = np.load(weight_path)
    weights = [data[f'arr_{i}'] for i in range(len(data.files))]
    return weights

def fed_avg_from_disk(folder_dir: str, client_scores: Dict[str, float]):
    """
    Load all weights from folder_dir, perform FedAvg, and update the model.
    - folder_dir: Directory containing client weights
    - client_scores: Dict mapping client_id to weight (e.g., sample count)
    """
    client_weights = load_all_weights(folder_dir)
    total_score = sum(client_scores.values())
    weighted_avg = None

    for client_id, weights in client_weights.items():
        score = client_scores.get(client_id, 0) / total_score
        if weighted_avg is None:
            weighted_avg = [score * layer for layer in weights]
        else:
            for i in range(len(weights)):
                weighted_avg[i] += score * weights[i]

    return weighted_avg

# %%
import sys
import os

# For Jupyter notebooks
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Import commonly used modules
from data_utils import *
from model_utils import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
from numba import cuda
import gc
from tensorflow.keras import backend as K
import numpy as np

from config_utils import load_config

# Load default config
CONFIG = load_config('../config/fl_template_config.yaml')

# Export commonly used items
__all__ = ['CONFIG']
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

history_dic = {}
model = create_model()
trainx,trainy = load_training_data(f'../experiments/{CONFIG['experiment_name']}/processed_data/init.npy')
history =  train_model(model,trainx,trainy)
history_dic['init'] = history
save_model(model,f'../experiments/{CONFIG['experiment_name']}/models/central_model.keras')
save_model_weights(model,'central_model',f'../experiments/fed_ml_experiment_1/model_weights/')
del model
K.clear_session()
gc.collect()

for i in range(CONFIG.get('num_clients',5)):
    model = create_model(seed = i+1)
    model._name = f'client_{i+1}'
    save_model(model,f'../experiments/{CONFIG['experiment_name']}/models/{model._name}.keras')
    history_dic[model._name] = {}
    del model
    K.clear_session()
    gc.collect()

for i in range(1,CONFIG['num_rounds']+1):
    
    local_training_history = {}
    
    central_weights = load_model_weights(f'../experiments/fed_ml_experiment_1/model_weights/central_model_weights.npz')
    
    for client in range(1,CONFIG['num_clients']+1):
        client_name = f'client_{client}'
        model_path = f'../experiments/{CONFIG['experiment_name']}/models/client_model_{client}.keras'
        model = load_model_from_disk(model_path)
        trainx,trainy = load_training_data(f'../experiments/{CONFIG['experiment_name']}/processed_data/client_{client}/round{i}.npy')

        #update model with global weight
        model.set_weights(central_weights)

        #training model on local data
        history = train_model(model,trainx,trainy)
        
        # local training history for central server
        local_training_history[client_name] = len(trainx)
        
        #model training history based on round
        history_dic[client_name][f'round_{i}'] = history

        #save model
        save_model(model,model_path)
        save_model_weights(model,client_name,f'../experiments/{CONFIG['experiment_name']}/model_weights/client_weights/')

        #clear model
        del model
        K.clear_session()
        gc.collect()
        
    ## Aggregate Weighted average
        fed_avg_from_disk(f'../experiments/{CONFIG['experiment_name']}/model_weights/client_weights/',local_training_history)
# Out:
# /home/yash/miniconda3/envs/fedml/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1743108662.660449   19610 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5582 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743108665.796871   19709 service.cc:152] XLA service 0x7fd50c00f980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743108665.797011   19709 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3070 Laptop GPU, Compute Capability 8.6
# 2025-03-27 14:51:05.869099: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1743108666.208393   19709 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6344 - auc: 0.5248 - loss: 1.1898 - precision: 0.7197 - recall: 0.4259
# I0000 00:00:1743108669.775522   19709 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 727ms/step - accuracy: 0.6235 - auc: 0.5452 - loss: 1.1168 - precision: 0.6877 - recall: 0.5327
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6147 - auc: 0.8527 - loss: 0.5932 - precision: 0.5867 - recall: 0.9803
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9183 - auc: 0.9530 - loss: 0.3457 - precision: 0.9136 - recall: 0.9321
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8928 - auc: 0.9644 - loss: 0.2260 - precision: 0.8990 - recall: 0.8816
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9097 - auc: 0.9635 - loss: 0.2466 - precision: 0.9131 - recall: 0.9173
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9465 - auc: 0.9799 - loss: 0.1888 - precision: 0.9452 - recall: 0.9607
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9533 - auc: 0.9851 - loss: 0.1613 - precision: 1.0000 - recall: 0.9044
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9633 - auc: 0.9835 - loss: 0.1365 - precision: 1.0000 - recall: 0.9231
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9888 - auc: 0.9988 - loss: 0.0543 - precision: 1.0000 - recall: 0.9803
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0300 - precision: 1.0000 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/central_model.keras
# 0

# %% [markdown]
# #### Client Models Initialization

# %%
for i in range(CONFIG.get('num_clients',5)):
    model = create_model(seed = i+1)
    model._name = f'client_{i+1}'
    save_model(model,f'../experiments/{CONFIG['experiment_name']}/models/{model._name}.keras')
    history_dic[model._name] = {}
    del model
    K.clear_session()
    gc.collect()
# Out:
# /home/yash/miniconda3/envs/fedml/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_1.keras
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_2.keras
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_3.keras
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_4.keras
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_5.keras

# %% [markdown]
# #### Local Train Client models and Global Aggregation

# %%
for i in range(1,CONFIG['num_rounds']+1):
    
    local_training_history = {}
    
    central_weights = load_model_weights(f'../experiments/fed_ml_experiment_1/model_weights/central_model_weights.npz')
    
    for client in range(1,CONFIG['num_clients']+1):
        client_name = f'client_{client}'
        model_path = f'../experiments/{CONFIG['experiment_name']}/models/client_model_{client}.keras'
        model = load_model_from_disk(model_path)
        trainx,trainy = load_training_data(f'../experiments/{CONFIG['experiment_name']}/processed_data/client_{client}/round{i}.npy')

        #update model with global weight
        model.set_weights(central_weights)

        #training model on local data
        history = train_model(model,trainx,trainy)
        
        # local training history for central server
        local_training_history[client_name] = len(trainx)
        
        #model training history based on round
        history_dic[client_name][f'round_{i}'] = history

        #save model
        save_model(model,model_path)
        save_model_weights(model,client_name,f'../experiments/{CONFIG['experiment_name']}/model_weights/client_weights/')

        #clear model
        del model
        K.clear_session()
        gc.collect()
        
    ## Aggregate Weighted average
        fed_avg_from_disk(f'../experiments/{CONFIG['experiment_name']}/model_weights/client_weights/',local_training_history)
# Out:
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 422ms/step - accuracy: 0.8505 - auc: 0.9044 - loss: 0.5914 - precision: 0.8555 - recall: 0.8811
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8401 - auc: 0.9668 - loss: 0.2947 - precision: 0.8459 - recall: 0.8895
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9494 - auc: 0.9900 - loss: 0.1770 - precision: 0.9800 - recall: 0.9291
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.
10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9807 - auc: 0.9995 - loss: 0.0346 - precision: 0.9702 - recall: 0.9883
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_3.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 426ms/step - accuracy: 0.8983 - auc: 0.9623 - loss: 0.3055 - precision: 0.9224 - recall: 0.8885
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9536 - auc: 0.9974 - loss: 0.0923 - precision: 0.9733 - recall: 0.9382
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9595 - auc: 0.9972 - loss: 0.1038 - precision: 0.9275 - recall: 1.0000
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9146 - auc: 0.9716 - loss: 0.2500 - precision: 1.0000 - recall: 0.8382
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9189 - auc: 0.9900 - loss: 0.1397 - precision: 0.9165 - recall: 0.9352
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9623 - auc: 0.9989 - loss: 0.0710 - precision: 0.9335 - recall: 1.0000
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9861 - auc: 0.9978 - loss: 0.0673 - precision: 1.0000 - recall: 0.9739
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9807 - auc: 1.0000 - loss: 0.0340 - precision: 0.9639 - recall: 1.0000
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0143 - precision: 1.0000 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0039 - precision: 1.0000 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 463ms/step - accuracy: 0.9156 - auc: 0.9677 - loss: 0.2251 - precision: 0.9445 - recall: 0.8935
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9245 - auc: 0.9703 - loss: 0.2018 - precision: 0.9319 - recall: 0.9243
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9892 - auc: 0.9985 - loss: 0.0644 - precision: 1.0000 - recall: 0.9800
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9861 - auc: 1.0000 - loss: 0.0418 - precision: 0.9745 - recall: 1.0000
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0112 - precision: 1.0000 - recall: 1.0000
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0021 - precision: 1.0000 - recall: 1.0000
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0019 - precision: 1.0000 - recall: 1.0000
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.2972e-04 - precision: 1.0000 - recall: 1.0000
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.1274e-04 - precision: 1.0000 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.4751e-04 - precision: 1.0000 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 451ms/step - accuracy: 0.7912 - auc: 0.8919 - loss: 0.7677 - precision: 0.7598 - recall: 0.8332
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9391 - auc: 0.9642 - loss: 0.2575 - precision: 0.9196 - recall: 0.9463
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8903 - auc: 0.9677 - loss: 0.2494 - precision: 0.8638 - recall: 0.9058
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9608 - auc: 0.9942 - loss: 0.1379 - precision: 1.0000 - recall: 0.9155
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9430 - auc: 0.9933 - loss: 0.1364 - precision: 0.9273 - recall: 0.9463
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9228 - auc: 0.9891 - loss: 0.1509 - precision: 0.9163 - recall: 0.9075
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8996 - auc: 0.9882 - loss: 0.2186 - precision: 0.8488 - recall: 0.9463
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9722 - auc: 0.9941 - loss: 0.1070 - precision: 1.0000 - recall: 0.9383
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9683 - auc: 0.9975 - loss: 0.1074 - precision: 0.9303 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9827 - auc: 0.9994 - loss: 0.0406 - precision: 1.0000 - recall: 0.9635
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_2.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 430ms/step - accuracy: 0.8604 - auc: 0.9295 - loss: 0.5115 - precision: 0.8881 - recall: 0.8056
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8163 - auc: 0.9609 - loss: 0.3833 - precision: 0.7538 - recall: 0.9244
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9352 - auc: 0.9604 - loss: 0.2734 - precision: 0.9318 - recall: 0.9285
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9576 - auc: 0.9603 - loss: 0.1867 - precision: 0.9798 - recall: 0.9285
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9630 - auc: 0.9907 - loss: 0.1097 - precision: 0.9915 - recall: 0.9285
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9807 - auc: 0.9894 - loss: 0.0909 - precision: 1.0000 - recall: 0.9585
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9668 - auc: 0.9978 - loss: 0.0733 - precision: 1.0000 - recall: 0.9285
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9722 - auc: 0.9938 - loss: 0.0700 - precision: 1.0000 - recall: 0.9401
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9722 - auc: 0.9994 - loss: 0.0528 - precision: 1.0000 - recall: 0.9401
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9753 - auc: 0.9987 - loss: 0.0453 - precision: 1.0000 - recall: 0.9469
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_2.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_3.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 493ms/step - accuracy: 0.8830 - auc: 0.9445 - loss: 0.4317 - precision: 0.9027 - recall: 0.8449
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8338 - auc: 0.9617 - loss: 0.4851 - precision: 0.7484 - recall: 0.9619
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9281 - auc: 0.9628 - loss: 0.1977 - precision: 1.0000 - recall: 0.8418
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9769 - auc: 0.9953 - loss: 0.1191 - precision: 0.9680 - recall: 0.9810
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9769 - auc: 0.9945 - loss: 0.0946 - precision: 0.9680 - recall: 0.9810
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9769 - auc: 0.9959 - loss: 0.0526 - precision: 0.9680 - recall: 0.9810
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9946 - auc: 0.9962 - loss: 0.0351 - precision: 1.0000 - recall: 0.9888
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9946 - auc: 0.9998 - loss: 0.0266 - precision: 1.0000 - recall: 0.9888
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9946 - auc: 1.0000 - loss: 0.0212 - precision: 1.0000 - recall: 0.9888
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9946 - auc: 0.9996 - loss: 0.0232 - precision: 1.0000 - recall: 0.9888
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_3.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s
10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9082 - auc: 0.9562 - loss: 0.2341 - precision: 0.9697 - recall: 0.7796
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9445 - auc: 0.9865 - loss: 0.1395 - precision: 0.9609 - recall: 0.8912
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9367 - auc: 0.9911 - loss: 0.1327 - precision: 1.0000 - recall: 0.8304
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9549 - auc: 0.9975 - loss: 0.0761 - precision: 0.9438 - recall: 0.9379
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9861 - auc: 1.0000 - loss: 0.0409 - precision: 1.0000 - recall: 0.9641
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9807 - auc: 0.9950 - loss: 0.0871 - precision: 0.9653 - recall: 0.9850
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9861 - auc: 0.9997 - loss: 0.0417 - precision: 1.0000 - recall: 0.9641
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9861 - auc: 1.0000 - loss: 0.0324 - precision: 0.9658 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9722 - auc: 1.0000 - loss: 0.0378 - precision: 1.0000 - recall: 0.9283
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 472ms/step - accuracy: 0.9354 - auc: 0.9363 - loss: 0.3895 - precision: 0.9198 - recall: 0.9584
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9408 - auc: 0.9871 - loss: 0.1559 - precision: 0.9428 - recall: 0.9405
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9532 - auc: 0.9953 - loss: 0.1242 - precision: 1.0000 - recall: 0.9057
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9610 - auc: 0.9983 - loss: 0.0873 - precision: 0.9668 - recall: 0.9551
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0339 - precision: 1.0000 - recall: 1.0000
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0130 - precision: 1.0000 - recall: 1.0000
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0055 - precision: 1.0000 - recall: 1.0000
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0015 - precision: 1.0000 - recall: 1.0000
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0018 - precision: 1.0000 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0014 - precision: 1.0000 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 449ms/step - accuracy: 0.8781 - auc: 0.9151 - loss: 0.5769 - precision: 0.8942 - recall: 0.8557
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8990 - auc: 0.9342 - loss: 0.3056 - precision: 0.9537 - recall: 0.8384
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9012 - auc: 0.9813 - loss: 0.1797 - precision: 0.9385 - recall: 0.8543
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9234 - auc: 0.9844 - loss: 0.1739 - precision: 0.9321 - recall: 0.9114
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9373 - auc: 0.9930 - loss: 0.1429 - precision: 0.9698 - recall: 0.9001
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9506 - auc: 0.9979 - loss: 0.0851 - precision: 1.0000 - recall: 0.8983
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9181 - auc: 0.9616 - loss: 0.3376 - precision: 0.9177 - recall: 0.9171
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9675 - auc: 0.9982 - loss: 0.0813 - precision: 0.9780 - recall: 0.9557
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9783 - auc: 0.9993 - loss: 0.0741 - precision: 1.0000 - recall: 0.9557
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.
10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9252 - auc: 0.9870 - loss: 0.1701 - precision: 0.9552 - recall: 0.9100
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9645 - auc: 0.9977 - loss: 0.0914 - precision: 0.9579 - recall: 0.9817
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9385 - auc: 0.9944 - loss: 0.1345 - precision: 0.9920 - recall: 0.8952
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9783 - auc: 0.9986 - loss: 0.0620 - precision: 0.9655 - recall: 1.0000
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9607 - auc: 0.9938 - loss: 0.1005 - precision: 0.9782 - recall: 0.9502
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9662 - auc: 0.9972 - loss: 0.0840 - precision: 0.9923 - recall: 0.9450
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 436ms/step - accuracy: 0.9279 - auc: 0.9643 - loss: 0.2472 - precision: 0.9440 - recall: 0.9277
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9430 - auc: 0.9731 - loss: 0.2140 - precision: 0.9947 - recall: 0.9035
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9506 - auc: 0.9934 - loss: 0.1334 - precision: 1.0000 - recall: 0.9100
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9484 - auc: 0.9975 - loss: 0.1049 - precision: 0.9495 - recall: 0.9625
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9644 - auc: 0.9837 - loss: 0.1737 - precision: 1.0000 - recall: 0.9389
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9900 - auc: 0.9992 - loss: 0.0632 - precision: 0.9828 - recall: 1.0000
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9783 - auc: 0.9990 - loss: 0.0789 - precision: 1.0000 - recall: 0.9625
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9862 - auc: 0.9998 - loss: 0.0252 - precision: 0.9826 - recall: 0.9926
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9946 - auc: 0.9998 - loss: 0.0272 - precision: 1.0000 - recall: 0.9898
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9900 - auc: 1.0000 - loss: 0.0156 - precision: 0.9828 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 452ms/step - accuracy: 0.9164 - auc: 0.9670 - loss: 0.2950 - precision: 0.9037 - recall: 0.9126
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9457 - auc: 0.9936 - loss: 0.1159 - precision: 0.9193 - recall: 0.9700
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9583 - auc: 0.9808 - loss: 0.1281 - precision: 1.0000 - recall: 0.9090
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9710 - auc: 0.9985 - loss: 0.0792 - precision: 0.9833 - recall: 0.9538
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9926 - auc: 0.9999 - loss: 0.0527 - precision: 1.0000 - recall: 0.9838
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9926 - auc: 1.0000 - loss: 0.0227 - precision: 1.0000 - recall: 0.9838
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0162 - precision: 1.0000 - recall: 1.0000
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0168 - precision: 1.0000 - recall: 1.0000
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0035 - precision: 1.0000 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0060 - precision: 1.0000 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_2.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 450ms/step - accuracy: 0.9153 - auc: 0.9542 - loss: 0.5417 - precision: 0.8971 - recall: 0.9257
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9641 - auc: 0.9901 - loss: 0.1128 - precision: 1.0000 - recall: 0.9288
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9907 - auc: 0.9849 - loss: 0.1417 - precision: 1.0000 - recall: 0.9823
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9907 - auc: 0.9931 - loss: 0.0837 - precision: 1.0000 - recall: 0.9823
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9946 - auc: 0.9903 - loss: 0.0787 - precision: 1.0000 - recall: 0.9896
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9946 - auc: 0.9906 - loss: 0.0764 - precision: 1.0000 - recall: 0.9896
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9946 - auc: 0.9947 - loss: 0.0467 - precision: 1.0000 - recall: 0.9896
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9946 - auc: 0.9985 - loss: 0.0400 - precision: 1.0000 - recall: 0.9896
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9946 - auc: 0.9993 - loss: 0.0400 - precision: 1.0000 - recall: 0.9896
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9946 - auc: 1.0000 - loss: 0.0242 - precision: 1.0000 - recall: 0.9896
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_2.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_3.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 483ms/step - accuracy: 0.9489 - auc: 0.9836 - loss: 0.1911 - precision: 0.9556 - recall: 0.9526
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8964 - auc: 0.9898 - loss: 0.2717 - precision: 0.8513 - recall: 0.9900
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8814 - auc: 0.9494 - loss: 0.3216 - precision: 1.0000 - recall: 0.7904
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9853 - auc: 0.9983 - loss: 0.1274 - precision: 0.9830 - recall: 0.9900
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9946 - auc: 0.9998 - loss: 0.0493 - precision: 1.0000 - recall: 0.9900
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9783 - auc: 0.9997 - loss: 0.0484 - precision: 1.0000 - recall: 0.9620
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0222 - precision: 1.0000 - recall: 1.0000
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9783 - auc: 1.0000 - loss: 0.0365 - precision: 1.0000 - recall: 0.9620
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0063 - precision: 1.0000 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0070 - precision: 1.0000 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_3.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 449ms/step - accuracy: 0.9205 - auc: 0.9697 - loss: 0.3050 - precision: 0.9113 - recall: 0.9373
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9437 - auc: 0.9934 - loss: 0.1182 - precision: 0.9727 - recall: 0.9235
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9422 - auc: 0.9826 - loss: 0.1682 - precision: 0.9653 - recall: 0.9282
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9946 - auc: 0.9995 - loss: 0.0722 - precision: 1.0000 - recall: 0.9900
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9584 - auc: 0.9998 - loss: 0.0712 - precision: 1.0000 - recall: 0.9235
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9783 - auc: 0.9996 - loss: 0.0810 - precision: 0.9545 - recall: 1.0000
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9473 - auc: 0.9607 - loss: 0.3989 - precision: 1.0000 - recall: 0.8817
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9907 - auc: 0.9990 - loss: 0.0776 - precision: 0.9927 - recall: 0.9900
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9601 - auc: 0.9983 - loss: 0.0576 - precision: 0.9538 - recall: 0.9667
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9210 - auc: 0.9979 - loss: 0.2534 - precision: 0.8635 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 468ms/step - accuracy: 0.9471 - auc: 0.9535 - loss: 0.2962 - precision: 0.9587 - recall: 0.9403
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9329 - auc: 0.9829 - loss: 0.2152 - precision: 0.9107 - recall: 0.9661
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - auc: 0.9875 - loss: 0.0973 - precision: 1.0000 - recall: 0.9403
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9623 - auc: 0.9934 - loss: 0.0929 - precision: 0.9554 - recall: 0.9735
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9823 - auc: 0.9937 - loss: 0.0758 - precision: 1.0000 - recall: 0.9661
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9861 - auc: 1.0000 - loss: 0.0388 - precision: 1.0000 - recall: 0.9735
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0122 - precision: 1.0000 - recall: 1.0000
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0129 - precision: 1.0000 - recall: 1.0000
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0017 - precision: 1.0000 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.1755e-04 - precision: 1.0000 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - accuracy: 0.9196 - auc: 0.9821 - loss: 0.1926 - precision: 0.8976 - recall: 0.9524
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9355 - auc: 0.9918 - loss: 0.1275 - precision: 0.9750 - recall: 0.8931
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9329 - auc: 0.9929 - loss: 0.1117 - precision: 0.9086 - recall: 0.9636
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9823 - auc: 0.9983 - loss: 0.0461 - precision: 1.0000 - recall: 0.9637
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9907 - auc: 0.9969 - loss: 0.0753 - precision: 1.0000 - recall: 0.9809
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9888 - auc: 0.9998 - loss: 0.0404 - precision: 0.9847 - recall: 0.9921
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9900 - auc: 1.0000 - loss: 0.0307 - precision: 1.0000 - recall: 0.9795
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9961 - auc: 0.9995 - loss: 0.0397 - precision: 1.0000 - recall: 0.9921
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9861 - auc: 0.9998 - loss: 0.0375 - precision: 1.0000 - recall: 0.9717
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9961 - auc: 0.9998 - loss: 0.0242 - precision: 1.0000 - recall: 0.9921
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_2.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 429ms/step - accuracy: 0.8453 - auc: 0.9230 - loss: 0.5653 - precision: 0.8401 - recall: 0.8863
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8550 - auc: 0.9647 - loss: 0.3072 - precision: 0.8250 - recall: 0.9317
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.
10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8987 - auc: 0.9288 - loss: 0.5022 - precision: 0.9095 - recall: 0.9293
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 480ms/step - accuracy: 0.9404 - auc: 0.9885 - loss: 0.2372 - precision: 0.9230 - recall: 0.9801
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9220 - auc: 0.9778 - loss: 0.2311 - precision: 0.9842 - recall: 0.8775
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8508 - auc: 0.9582 - loss: 0.3062 - precision: 0.9643 - recall: 0.7603
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8871 - auc: 0.9571 - loss: 0.2451 - precision: 0.9147 - recall: 0.8838
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9501 - auc: 0.9933 - loss: 0.1068 - precision: 0.9589 - recall: 0.9533
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9590 - auc: 0.9989 - loss: 0.0849 - precision: 0.9899 - recall: 0.9377
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0343 - precision: 1.0000 - recall: 1.0000
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9729 - auc: 0.9998 - loss: 0.0452 - precision: 0.9901 - recall: 0.9632
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0211 - precision: 1.0000 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0121 - precision: 1.0000 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 472ms/step - accuracy: 0.9200 - auc: 0.9321 - loss: 0.4632 - precision: 0.8686 - recall: 0.9337
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9619 - auc: 0.9978 - loss: 0.1076 - precision: 0.9064 - recall: 1.0000
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9434 - auc: 0.9848 - loss: 0.1519 - precision: 1.0000 - recall: 0.8534
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9783 - auc: 0.9998 - loss: 0.0776 - precision: 0.9430 - recall: 1.0000
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9729 - auc: 0.9976 - loss: 0.0756 - precision: 0.9427 - recall: 0.9869
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9823 - auc: 0.9997 - loss: 0.0297 - precision: 0.9905 - recall: 0.9617
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9783 - auc: 1.0000 - loss: 0.0266 - precision: 0.9430 - recall: 1.0000
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0096 - precision: 1.0000 - recall: 1.0000
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0178 - precision: 1.0000 - recall: 1.0000
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9946 - auc: 0.9998 - loss: 0.0209 - precision: 1.0000 - recall: 0.9869
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_1.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_2.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 464ms/step - accuracy: 0.9494 - auc: 0.9980 - loss: 0.0985 - precision: 0.8825 - recall: 0.9758
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9606 - auc: 1.0000 - loss: 0.0686 - precision: 1.0000 - recall: 0.8784
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9961 - auc: 0.9922 - loss: 0.0369 - precision: 1.0000 - recall: 0.9879
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9760 - auc: 0.9907 - loss: 0.0716 - precision: 1.0000 - recall: 0.9264
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9823 - auc: 0.9977 - loss: 0.0647 - precision: 1.0000 - recall: 0.9456
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.
10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0121 - precision: 1.0000 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_2.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_3.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 452ms/step - accuracy: 0.9222 - auc: 0.9594 - loss: 0.2778 - precision: 0.9065 - recall: 0.9386
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9421 - auc: 0.9747 - loss: 0.1684 - precision: 1.0000 - recall: 0.8810
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9495 - auc: 0.9648 - loss: 0.1833 - precision: 1.0000 - recall: 0.8960
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9421 - auc: 0.9690 - loss: 0.1741 - precision: 1.0000 - recall: 0.8810
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9634 - auc: 0.9901 - loss: 0.1243 - precision: 1.0000 - recall: 0.9248
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9634 - auc: 0.9846 - loss: 0.1156 - precision: 1.0000 - recall: 0.9248
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9772 - auc: 0.9978 - loss: 0.0805 - precision: 1.0000 - recall: 0.9536
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9900 - auc: 0.9907 - loss: 0.0795 - precision: 1.0000 - recall: 0.9796
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9827 - auc: 0.9993 - loss: 0.0585 - precision: 1.0000 - recall: 0.9646
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9900 - auc: 0.9880 - loss: 0.0716 - precision: 1.0000 - recall: 0.9796
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_3.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 447ms/step - accuracy: 0.9333 - auc: 0.9544 - loss: 0.2973 - precision: 0.9395 - recall: 0.9523
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9378 - auc: 0.9902 - loss: 0.1454 - precision: 0.9784 - recall: 0.9176
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9861 - auc: 0.9905 - loss: 0.0992 - precision: 1.0000 - recall: 0.9772
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9861 - auc: 1.0000 - loss: 0.0545 - precision: 1.0000 - recall: 0.9772
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9946 - auc: 0.9998 - loss: 0.0280 - precision: 0.9911 - recall: 1.0000
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9492 - auc: 0.9988 - loss: 0.0892 - precision: 0.9877 - recall: 0.9265
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0176 - precision: 1.0000 - recall: 1.0000
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9900 - auc: 1.0000 - loss: 0.0235 - precision: 0.9841 - recall: 1.0000
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9861 - auc: 1.0000 - loss: 0.0276 - precision: 1.0000 - recall: 0.9772
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9946 - auc: 0.9930 - loss: 0.0554 - precision: 0.9911 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_4.keras
# 📦 Model loaded from: ../experiments/fed_ml_experiment_1/models/client_model_5.keras
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 437ms/step - accuracy: 0.8825 - auc: 0.9541 - loss: 0.3817 - precision: 0.8725 - recall: 0.8869
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8321 - auc: 0.9164 - loss: 0.6250 - precision: 0.7851 - recall: 0.9150
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9015 - auc: 0.9446 - loss: 0.2822 - precision: 1.0000 - recall: 0.7955
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8873 - auc: 0.9773 - loss: 0.2333 - precision: 0.8546 - recall: 0.9273
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9371 - auc: 0.9953 - loss: 0.1256 - precision: 0.9826 - recall: 0.8841
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9590 - auc: 0.9987 - loss: 0.0657 - precision: 0.9587 - recall: 0.9575
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9683 - auc: 0.9925 - loss: 0.1172 - precision: 1.0000 - recall: 0.9358
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9900 - auc: 0.9994 - loss: 0.0331 - precision: 0.9790 - recall: 1.0000
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9900 - auc: 1.0000 - loss: 0.0314 - precision: 1.0000 - recall: 0.9783
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9861 - auc: 1.0000 - loss: 0.0532 - precision: 0.9712 - recall: 1.0000
# 💾 Model saved to: ../experiments/fed_ml_experiment_1/models/client_model_5.keras

# %%
history_dic
# Out:
# {'init': <keras.src.callbacks.history.History at 0x7fd623ba7f80>,
#  'client_model_1': {},
#  'client_model_2': {},
#  'client_model_3': {},
#  'client_model_4': {},
#  'client_model_5': {},
#  'client_1': {'round_1': <keras.src.callbacks.history.History at 0x7fd56451a480>,
#   'round_2': <keras.src.callbacks.history.History at 0x7fd518242090>,
#   'round_3': <keras.src.callbacks.history.History at 0x7fd51908c920>,
#   'round_4': <keras.src.callbacks.history.History at 0x7fd51aa4fbf0>,
#   'round_5': <keras.src.callbacks.history.History at 0x7fd5196b1460>,
#   'round_6': <keras.src.callbacks.history.History at 0x7fd51029c920>,
#   'round_7': <keras.src.callbacks.history.History at 0x7fd51226a090>,
#   'round_8': <keras.src.callbacks.history.History at 0x7fd5134b6d50>,
#   'round_9': <keras.src.callbacks.history.History at 0x7fd51203a480>,
#   'round_10': <keras.src.callbacks.history.History at 0x7fd4d68b8920>},
#  'client_2': {'round_1': <keras.src.callbacks.history.History at 0x7fd58443c440>,
#   'round_2': <keras.src.callbacks.history.History at 0x7fd5182d01a0>,
#   'round_3': <keras.src.callbacks.history.History at 0x7fd519c02480>,
#   'round_4': <keras.src.callbacks.history.History at 0x7fd51af07ce0>,
#   'round_5': <keras.src.callbacks.history.History at 0x7fd518a53740>,
#   'round_6': <keras.src.callbacks.history.History at 0x7fd511c12d50>,
#   'round_7': <keras.src.callbacks.history.History at 0x7fd51217ad50>,
#   'round_8': <keras.src.callbacks.history.History at 0x7fd511fb2090>,
#   'round_9': <keras.src.callbacks.history.History at 0x7fd5107d9130>,
#   'round_10': <keras.src.callbacks.history.History at 0x7fd4d63f3980>},
#  'client_3': {'round_1': <keras.src.callbacks.history.History at 0x7fd55c609460>,
#   'round_2': <keras.src.callbacks.history.History at 0x7fd5104ff500>,
#   'round_3': <keras.src.callbacks.history.History at 0x7fd51a10dbe0>,
#   'round_4': <keras.src.callbacks.history.History at 0x7fd51ac59460>,
#   'round_5': <keras.src.callbacks.history.History at 0x7fd51029e3f0>,
#   'round_6': <keras.src.callbacks.history.History at 0x7fd5124a5d60>,
#   'round_7': <keras.src.callbacks.history.History at 0x7fd513af4920>,
#   'round_8': <keras.src.callbacks.history.History at 0x7fd51012dd60>,
#   'round_9': <keras.src.callbacks.history.History at 0x7fd4d43b1130>,
#   'round_10': <keras.src.callbacks.history.History at 0x7fd4d7d35d60>},
#  'client_4': {'round_1': <keras.src.callbacks.history.History at 0x7fd55c625d60>,
#   'round_2': <keras.src.callbacks.history.History at 0x7fd51b7a9460>,
#   'round_3': <keras.src.callbacks.history.History at 0x7fd51a165d60>,
#   'round_4': <keras.src.callbacks.history.History at 0x7fd51abe1460>,
#   'round_5': <keras.src.callbacks.history.History at 0x7fd5115a7ce0>,
#   'round_6': <keras.src.callbacks.history.History at 0x7fd51295ad50>,
#   'round_7': <keras.src.callbacks.history.History at 0x7fd51378dd60>,
#   'round_8': <keras.src.callbacks.history.History at 0x7fd4d47cad50>,
#   'round_9': <keras.src.callbacks.history.History at 0x7fd5108dc920>,
#   'round_10': <keras.src.callbacks.history.History at 0x7fd4d79091f0>},
#  'client_5': {'round_1': <keras.src.callbacks.history.History at 0x7fd53828ad50>,
#   'round_2': <keras.src.callbacks.history.History at 0x7fd51b68ad50>,
#   'round_3': <keras.src.callbacks.history.History at 0x7fd519972d50>,
#   'round_4': <keras.src.callbacks.history.History at 0x7fd51a4b7ce0>,
#   'round_5': <keras.src.callbacks.history.History at 0x7fd5115cad50>,
#   'round_6': <keras.src.callbacks.history.History at 0x7fd512652090>,
#   'round_7': <keras.src.callbacks.history.History at 0x7fd5134b4920>,
#   'round_8': <keras.src.callbacks.history.History at 0x7fd510bba090>,
#   'round_9': <keras.src.callbacks.history.History at 0x7fd4d6b1bb90>,
#   'round_10': <keras.src.callbacks.history.History at 0x7fd4d7989130>}}

# %%
save_model_weights(model,'client_1','../experiments/fed_ml_experiment_1/model_weights/client_weights')
save_model_weights(model,'client_2','../experiments/fed_ml_experiment_1/model_weights/client_weights')
save_model_weights(model,'client_3','../experiments/fed_ml_experiment_1/model_weights/client_weights')

# %%
weights = load_model_weights('../experiments/fed_ml_experiment_1/model_weights/client_weights/client_1_weights.npz')

# %%
client_scores = {
    "client_1":1,
    "client_2":1,
    "client_3":3,
}
avg = fed_avg_from_disk('../experiments/fed_ml_experiment_1/model_weights/client_weights/',client_scores)
# Out:
# [array([[[[ 0.10040593, -0.06353728, -0.10933036,  0.12259068,
#            -0.00766506, -0.08605964,  0.01866475, -0.09534668,
#             0.05138377, -0.0103279 , -0.10331773, -0.07375038,
#             0.09672261, -0.0781009 ,  0.00721616,  0.08586128,
#             0.1030162 ,  0.01892288, -0.06343832, -0.01815641,
#            -0.08469357,  0.01792   , -0.07774559, -0.03122025,
#             0.00111724, -0.09655579, -0.0255607 , -0.07044204,
#            -0.01266762, -0.01372485, -0.02474237, -0.1419318 ],
#           [ 0.12325376, -0.04511715, -0.10395281, -0.07862566,
#            -0.05807437, -0.04046233, -0.10179633, -0.13416488,
#            -0.09728852,  0.05542186,  0.02888137,  0.08262793,
#            -0.07425914,  0.08575132,  0.10671686, -0.03873877,
#            -0.00642935,  0.11563914,  0.02881887,  0.08512037,
#            -0.11567664,  0.07414966, -0.04480654, -0.06381175,
#            -0.08882004,  0.0845435 ,  0.00664516,  0.10599338,
#             0.08692296,  0.01289197, -0.02154739, -0.05946649],
#            -0.0551286 ,  0.07783342],
#           [ 0.0717792 , -0.01674184,  0.0898049 , ..., -0.08638351,
#            -0.06326173,  0.01296871],
#           ...,
#           [-0.05506108,  0.03671127, -0.07091789, ..., -0.04654052,
#             0.02318775,  0.02543442],
#           [ 0.02501782,  0.08863447, -0.00425022, ...,  0.05225679,
#            -0.07026676,  0.05993667],
#           [-0.01810627,  0.04442842,  0.0647079 , ...,  0.00966404,
#            -0.05843018, -0.01724629]],
#
#          [[ 0.028334  , -0.09943125,  0.03728177, ...,  0.04786381,
#             0.05975271,  0.05323377],
#           [-0.06539304,  0.04466015,  0.00942937, ..., -0.01623914,
#            -0.02460039, -0.0067654 ],
#           [ 0.06438527, -0.06596036,  0.07894071, ..., -0.00133754,
#            -0.00937682, -0.06709221],
#           ...,
#           [-0.055242  ,  0.02500216, -0.03299505, ...,  0.06558096,
#            -0.00839773,  0.0618684 ],
#           [-0.02938188,  0.09127089, -0.06285667, ..., -0.09436637,
#             0.08027239,  0.04692206],
#           [-0.04020112, -0.0463113 , -0.0451224 , ..., -0.04483072,
#            -0.01053876, -0.00934172]],
#
#          [[ 0.03879339,  0.03322081, -0.06761746, ..., -0.00189397,
#             0.03493643, -0.05357452],
#           [ 0.0001554 , -0.04741561, -0.07930317, ..., -0.03655345,
#            -0.05475535,  0.05834522],
#           [-0.06624339,  0.00836669, -0.03061941, ..., -0.06951096,
#            -0.01190073, -0.00209005],
#           ...,
#           [ 0.00515105, -0.04758211, -0.06596798, ..., -0.03335469,
#             0.03541786, -0.07515041],
#           [-0.01194267,  0.01687909, -0.0705898 , ...,  0.05606797,
#             0.00031024, -0.05682752],
#           [-0.06377032,  0.02240078,  0.0325281 , ...,  0.02344265,
#            -0.00783847,  0.00323123]]],
#
#
#         [[[-0.04955222, -0.07642807,  0.01184176, ..., -0.01025565,
#            -0.05417854,  0.05791688],
#           [ 0.06205809, -0.07090598, -0.05251357, ..., -0.05425725,
#             0.02359675, -0.03876052],
#           [-0.06219081, -0.07765567,  0.02169101, ..., -0.07341403,
#            -0.03966621, -0.07186167],
#           ...,
#           [ 0.05341027, -0.01765099,  0.06088398, ..., -0.03475287,
#             0.07822135, -0.0054009 ],
#           [-0.03402353, -0.0434343 , -0.08769262, ...,  0.02655819,
#             0.00665272,  0.0069688 ],
#           [-0.05375701, -0.0204848 , -0.0585878 , ...,  0.00683564,
#             0.0717441 , -0.01122931]],
#
#          [[ 0.04855012, -0.02001099,  0.01497083, ..., -0.04551328,
#            -0.02931614, -0.0127839 ],
#           [-0.00674422, -0.01117054, -0.01084249, ..., -0.02923043,
#            -0.06976076, -0.08140556],
#           [-0.05729954, -0.08135815, -0.00371197, ..., -0.07637548,
#             0.08541834, -0.01072363],
#           ...,
#           [-0.02405536, -0.04154595,  0.02201708, ..., -0.02778226,
#             0.00330165, -0.00561206],
#           [ 0.06176732, -0.06719292,  0.02352342, ..., -0.02606433,
#             0.02311879, -0.08030541],
#           [-0.03309663,  0.07406383, -0.01963118, ..., -0.00228034,
#             0.04487389, -0.0888487 ]],
#         -6.9410959e-04, -5.9978440e-03, -1.1997253e-03,  1.5209882e-03],
#        dtype=float32),
#  array([[-0.18521002],
#         [-0.12792021],
#         [ 0.23138899],
#         [ 0.2648799 ],
#         [ 0.26473972],
#         [-0.00091286],
#         [ 0.15790777],
#         [-0.07094564],
#         [-0.24311948],
#         [ 0.02054174],
#         [ 0.14304066],
#         [ 0.27636722],
#         [ 0.25787154],
#         [-0.02496137],
#         [-0.17746706],
#         [ 0.00900341],
#         [-0.142552  ],
#         [ 0.10985214],
#         [-0.24935211],
#         [-0.07093223],
#         [-0.29020205],
#         [ 0.17029575],
#         [ 0.29198548],
#         [-0.14131512],
#         [-0.11160421],
#         [-0.21005836],
#         [-0.1060435 ],
#         [ 0.13674372],
#         [-0.28877923],
#         [-0.17095105],
#         [-0.0812849 ],
#         [ 0.07828683],
#         [-0.15075292],
#         [ 0.01734434],
#         [-0.13002087],
#         [ 0.13640702],
#         [ 0.04684564],
#         [-0.1698804 ],
#         [ 0.26817146],
#         [-0.04109036],
#         [-0.09297217],
#         [-0.1993143 ],
#         [ 0.16004762],
#         [-0.15976126],
#         [-0.2561171 ],
#         [ 0.07624543],
#         [ 0.1009112 ],
#         [ 0.04276925],
#         [ 0.06931934],
#         [-0.1841844 ],
#         [ 0.29051593],
#         [-0.2578476 ],
#         [ 0.11055125],
#         [-0.1662854 ],
#         [-0.24759284],
#         [ 0.1208099 ],
#         [ 0.22067416],
#         [ 0.17213689],
#         [-0.01338406],
#         [-0.1951099 ],
#         [ 0.2164864 ],
#         [-0.25026965],
#         [ 0.1661909 ],
#         [-0.24087541]], dtype=float32),
#  array([-0.00468742], dtype=float32)]

# %% [markdown]
# ## FedAvg Conditioned

# %% [markdown]
# ### Modified FedAvg with Performance-based Weighting
#
# ### Server Initialization:
# Initialize global model weights W₀
#
# ### Main Federated Learning Loop:
#
# For each round t = 1 to T:
#
#     1. Select a subset of clients Sₜ (or use all available clients)
#     2. Broadcast the current global model weights Wₜ to all clients in Sₜ
#
#     3. For each client k in Sₜ (executed in parallel):
#          - Perform a local update:
#            Wₜᵏ = ClientUpdate(Wₜ, local_dataₖ)
#          - Evaluate the updated model on a common validation set:
#            aₖ = Evaluate(Wₜᵏ, validation_set)  # e.g., accuracy
#          - Return updated model Wₜᵏ, number of samples nₖ, and accuracy aₖ
#
#     4. Aggregate the updated weights:
#          - Compute the performance-weighted sum of samples:
#            Total_weight = Σₖ₍∈Sₜ₎ (nₖ × aₖ)
#          - Update global model weights:
#            Wₜ₊₁ = Σₖ₍∈Sₜ₎ [(nₖ × aₖ) / Total_weight] × Wₜᵏ
#
# Return final global model weights W_T
#
# ### ClientUpdate Function:
#
# Function ClientUpdate(W, local_data):
#
#     Set W_local = W
#     For each local epoch e = 1 to E:
#          For each batch b in local_data:
#               - Compute gradient: grad = ∇(loss(W_local, b))
#               - Update local weights: W_local = W_local - learning_rate * grad
#     Return W_local

# %% [markdown]
# ## Asynchronous Weight Updating Federated Learning

# %% [markdown]
# ### Federated Learning with Partial Weight Sharing (Deep Layers Updated Frequently)
#
# ### Server Initialization:
# Initialize global shallow weights W_shallow₀
# Initialize global deep weights W_deep₀
# Set shallow_update_interval K  # e.g., update shallow layers every K rounds, update deep layers every round
#
# ### Main Federated Learning Loop:
#
# For each round t = 1 to T:
#
#     1. Determine if this is a shallow update round:
#          If (t mod K == 0):
#              shallow_update = True
#          Else:
#              shallow_update = False
#
#     2. Client Selection & Broadcast:
#          Select a subset of clients Sₜ
#          For each client in Sₜ, send:
#              - Current deep weights: W_deepₜ  (always sent)
#              - If shallow_update is True, also send current shallow weights: W_shallowₜ
#              - Otherwise, clients use their locally stored shallow weights
#
#     3. Clients' Local Update (executed in parallel):
#          For each client k in Sₜ:
#              - If shallow_update is True:
#                   (W_shallowₜ^k, W_deepₜ^k) = ClientUpdate(W_shallowₜ, W_deepₜ, local_dataₖ, update_shallow=True)
#              - Else:
#                   (W_shallow_local, W_deepₜ^k) = ClientUpdate(W_shallow_local, W_deepₜ, local_dataₖ, update_shallow=False)
#              - Evaluate the full updated model on a common validation set:
#                   aₖ = Evaluate(FullModel(W_shallow, W_deep), validation_set)  # e.g., accuracy
#              - Return to server:
#                   - For shallow layers: if update_shallow is True, return updated W_shallowₜ^k; otherwise, no update (or the previous version)
#                   - Updated deep weights: W_deepₜ^k
#                   - Local sample count nₖ and performance metric aₖ
#
#     4. Server Aggregation:
#          # Always aggregate deep layers:
#          Compute Total_weight_deep = Σₖ₍∈Sₜ₎ (nₖ × aₖ)
#          Update global deep weights:
#              W_deepₜ₊₁ = Σₖ₍∈Sₜ₎ [ (nₖ × aₖ) / Total_weight_deep ] × W_deepₜ^k
#
#          # Aggregate shallow layers only on shallow update rounds:
#          If shallow_update is True:
#              Compute Total_weight_shallow = Σₖ₍∈Sₜ₎ (nₖ × aₖ)
#              Update global shallow weights:
#                  W_shallowₜ₊₁ = Σₖ₍∈Sₜ₎ [ (nₖ × aₖ) / Total_weight_shallow ] × W_shallowₜ^k
#          Else:
#              W_shallowₜ₊₁ = W_shallowₜ  # Keep shallow layers unchanged
#
#     Return final global model: {W_shallow_T, W_deep_T}
#
#
# ### ClientUpdate Function:
#
# Function ClientUpdate(shallow_weights, deep_weights, local_data, update_shallow):
#
#     If update_shallow is True:
#          Set local_shallow = shallow_weights    # Received from server
#     Else:
#          Set local_shallow = local_shallow      # Use previously stored shallow weights locally
#
#     Set local_deep = deep_weights              # Always use the latest deep weights from server
#
#     For each local epoch e = 1 to E:
#          For each batch b in local_data:
#               If update_shallow is True:
#                   - Compute gradients for both layers:
#                         grad_shallow, grad_deep = ∇(loss(FullModel(local_shallow, local_deep), b))
#                   - Update shallow layers:
#                         local_shallow = local_shallow - learning_rate * grad_shallow
#               Else:
#                   - Compute gradient only for deep layers (shallow remains fixed):
#                         grad_deep = ∇(loss(FullModel(local_shallow, local_deep), b))
#               - Update deep layers:
#                     local_deep = local_deep - learning_rate * grad_deep
#
#     If update_shallow is True:
#          Return (local_shallow, local_deep)
#     Else:
#          Return (local_shallow, local_deep)  # Note: shallow remains unchanged from before the round
